# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import torch; torch.manual_seed(0)
import torch.nn as nn
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from data import AnimeFaces

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'; device
# Out:
# 'cuda'

# %%
dataset = AnimeFaces('./data/anime_faces', device=device)
data = DataLoader(dataset, batch_size=512, shuffle=True)
# Out:
# Reading dataset into cuda memory... done

# %%
def imshow(x): plt.imshow(x.permute(1,2,0).detach().cpu())

# %%
imshow(dataset[2])
